# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#'''CLASSIFICATION'''
#BINARY CLASSIFICATION

# %% [markdown]
# Y--->Satisfication column
# x--> iske basis pe hum y nikalenge

# %%
df=pd.read_csv('https://raw.githubusercontent.com/upflairs-pvt-ltd/1st_june_data_science/master/customer_satisfaction/cust_satisfaction.csv')
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# ...

# %%
df.tail()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# ...

# %%
df.shape
# Out:
# (103904, 12)

# %%
df.duplicated().sum()
# Out:
# 172

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.dropna(inplace=True) #delete all rows that contain missing values--->by default rows

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
female=df[df['Gender']=='Female']
female
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# 7       Female     Loyal Customer  Business travel  Business
# 8       Female     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103893  Female     Loyal Customer  Business travel  Business
# 103895  Female  disloyal Customer  Business travel       Eco
# 103897  Female     Loyal Customer  Business travel  Business
# 103899  Female  disloyal Customer  Business travel       Eco
# 103902  Female  disloyal Customer  Business travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 2                     satisfied   26             1142                       5
# ...

# %%
male=df[df['Gender']=='Male']
male
# Out:
#        Gender      Customer Type   Type of Travel     Class  \
# 0        Male     Loyal Customer  Personal Travel  Eco Plus
# 1        Male  disloyal Customer  Business travel  Business
# 4        Male     Loyal Customer  Business travel  Business
# 6        Male     Loyal Customer  Personal Travel       Eco
# 9        Male  disloyal Customer  Business travel       Eco
# ...       ...                ...              ...       ...
# 103896   Male     Loyal Customer  Business travel       Eco
# 103898   Male     Loyal Customer  Personal Travel       Eco
# 103900   Male     Loyal Customer  Business travel  Business
# 103901   Male  disloyal Customer  Business travel  Business
# 103903   Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
female.shape
# Out:
# (52576, 12)

# %%
male.shape
# Out:
# (51018, 12)

# %%
female['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    30107
# satisfied                  22469
# Name: count, dtype: int64

# %%
male['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    28590
# satisfied                  22428
# Name: count, dtype: int64

# %%
female['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    36433
# Personal Travel    16143
# Name: count, dtype: int64

# %%
male['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    35032
# Personal Travel    15986
# Name: count, dtype: int64

# %%
female['Class'].value_counts()
# Out:
# Class
# Business    24868
# Eco         23776
# Eco Plus     3932
# Name: count, dtype: int64

# %%
male['Class'].value_counts()
# Out:
# Class
# Business    24665
# Eco         22817
# Eco Plus     3536
# Name: count, dtype: int64

# %%
female['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       42336
# disloyal Customer    10240
# Name: count, dtype: int64

# %%
male['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       42326
# disloyal Customer     8692
# Name: count, dtype: int64

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
sns.countplot(x='Customer Type',data=df,hue='Gender')
# Out:
# <AxesSubplot: xlabel='Customer Type', ylabel='count'>

# %%
sns.countplot(x='satisfaction',data=df,hue='Gender')
# Out:
# <AxesSubplot: xlabel='satisfaction', ylabel='count'>

# %%
sns.countplot(x='Class',data=df,hue='Gender')
# Out:
# <AxesSubplot: xlabel='Class', ylabel='count'>

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
sns.relplot(x='Departure Delay in Minutes',y='Arrival Delay in Minutes',data=df) #linear and positive relationship

# %%
sns.relplot(x='Departure Delay in Minutes',y='Arrival Delay in Minutes',data=df,col='Class') #linear and positive relationship

# %%
plt.scatter(x=df['Arrival Delay in Minutes'],y=[''])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 plt.scatter(x=df['Arrival Delay in Minutes'],y=[''])
#       2 plt.show()
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2798, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2793 @_copy_docstring_and_deprecators(Axes.scatter)
#    2794 def scatter(
#    2795         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2796         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2797         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2798     __ret = gca().scatter(
#    2799         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2800         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...

# %%
df['Age'].min()
# Out:
# 7

# %%
df['Age'].max()
# Out:
# 85

# %%
sns.histplot(df['Age'],bins=[5,20,35,50,70,85,90])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 5208.,  9936., 17515., 15607., 17553., 17167., 13563.,  5676.,
#          1199.,   170.]),
#  array([ 7. , 14.8, 22.6, 30.4, 38.2, 46. , 53.8, 61.6, 69.4, 77.2, 85. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x='Inflight entertainment',data=df,hue='Gender')
plt.title("Entertainment")
plt.show()

# %%
sns.countplot(x='Baggage handling',data=df,hue='Gender')
# Out:
# <AxesSubplot: xlabel='Baggage handling', ylabel='count'>

# %%
#data for balance or imbalance
sns.countplot(df['satisfaction'])
plt.title("Balance or Imbalance")
plt.show()

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58697
# satisfied                  44897
# Name: count, dtype: int64

# %%
df.head()

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,OrdinalEncoder

# %%
df2= pd.get_dummies(df,drop_first="if_binary").astype(int)

# %%
df2.head()
# Out:
#    Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0   13              460                       5                 4
# 1   25              235                       1                 3
# 2   26             1142                       5                 4
# 3   25              562                       2                 3
# 4   61              214                       3                 4
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                        18
# 1            1                           1                         6
# 2            5                           0                         0
# 3            2                          11                         9
# 4            3                           0                         0
#
#    Gender_Male  Customer Type_disloyal Customer  \
# 0            1                                0
# 1            1                                1
# ...

# %%
df2.isnull().sum()
# Out:
# Age                                0
# Flight Distance                    0
# Inflight entertainment             0
# Baggage handling                   0
# Cleanliness                        0
# Departure Delay in Minutes         0
# Arrival Delay in Minutes           0
# Gender_Male                        0
# Customer Type_disloyal Customer    0
# Type of Travel_Personal Travel     0
# Class_Eco                          0
# Class_Eco Plus                     0
# satisfaction_satisfied             0
# dtype: int64

# %%
#x and y split, independent and dependent variable
x=df2.drop("satisfaction_satisfied",axis='columns') #independent variable
y=df2[['satisfaction_satisfied']] #target variable

# %%
#training and testing split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.head()
# Out:
#        Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 64017   40             2354                       1                 1
# 38151   33             2704                       4                 5
# 46831   18              308                       2                 4
# 89595   40             1846                       2                 5
# 64725   36             1635                       1                 3
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 64017            4                          26                        21
# 38151            1                          10                         0
# 46831            2                           0                         3
# 89595            2                          12                         0
# 64725            1                           0                         0
#
#        Gender_Male  Customer Type_disloyal Customer  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr = LogisticRegression()

# %%
y_train.values.ravel()
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
## train the algorithm 
lgr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# LogisticRegression()
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
print("Training score : ",lgr.score(x_train,y_train)*100) 
print("Testing score : ",lgr.score(x_test,y_test)*100 )
# Out:
# Training score :  79.70437405731523
# Testing score :  79.65635407114243

# %%
pred=lgr.predict(x_test)

# %%
x_test.shape
# Out:
# (20719, 12)

# %%
pred
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
y_test['prediction']=pred #actual

# %%
y_test.head(40)
# Out:
#         satisfaction_satisfied  prediction
# 73295                        0           0
# 89131                        0           0
# 39339                        1           1
# 49218                        0           0
# 58416                        0           0
# 82091                        1           1
# 5874                         0           0
# 13435                        1           1
# 14779                        0           0
# 92987                        0           1
# 50577                        0           0
# 61565                        0           0
# 8959                         0           1
# 72743                        0           0
# 100586                       1           1
# 93284                        1           1
# 90721                        0           0
# 8629                         0           1
# 84559                        0           0
# 591                          0           0
# 55478                        0           0
# ...

# %%
y_test.shape
# Out:
# (20719, 2)

# %% [markdown]
# MODEL EVALUATION

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
# confusion_matrix(actual,prediction)  
matrix = confusion_matrix(y_test['satisfaction_satisfied'],y_test['prediction'])  
matrix
# Out:
# array([[9401, 2362],
#        [1853, 7103]])

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.heatmap(matrix,annot=True,fmt='d')    # d ==> decimal 
plt.title('CONFUSION MATRIX')
plt.axis('off')
plt.show()

# %%
import os, joblib 
os.makedirs('models',exist_ok=True) 
joblib.dump(lgr,'./models/logisticregre.lb') 
print('your model is saved!')
# Out:
# your model is saved!

# %%
print(classification_report(y_test['satisfaction_satisfied'],y_test['prediction']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82     11763
#            1       0.75      0.79      0.77      8956
#
#     accuracy                           0.80     20719
#    macro avg       0.79      0.80      0.79     20719
# weighted avg       0.80      0.80      0.80     20719

# %%
x_train.head()
# Out:
#        Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 64017   40             2354                       1                 1
# 38151   33             2704                       4                 5
# 46831   18              308                       2                 4
# 89595   40             1846                       2                 5
# 64725   36             1635                       1                 3
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 64017            4                          26                        21
# 38151            1                          10                         0
# 46831            2                           0                         3
# 89595            2                          12                         0
# 64725            1                           0                         0
#
#        Gender_Male  Customer Type_disloyal Customer  \
# ...

# %%
y_test
# Out:
#        satisfaction_satisfied  prediction
# 73295                       0           0
# 89131                       0           0
# 39339                       1           1
# 49218                       0           0
# 58416                       0           0
# ...                       ...         ...
# 86823                       0           1
# 73304                       0           0
# 67853                       1           0
# 57575                       1           1
# 64861                       1           0
#
# [20719 rows x 2 columns]

# %%
x_test
# Out:
#        Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 73295   22              175                       4                 5
# 89131   22              192                       2                 3
# 39339   43             2435                       5                 5
# 49218   12              792                       5                 4
# 58416   21              624                       3                 2
# ...    ...              ...                     ...               ...
# 86823   13             1452                       3                 4
# 73304   22             2139                       4                 3
# 67853   40             1814                       5                 3
# 57575   56              224                       5                 5
# 64861   23              701                       1                 5
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# ...

# %%
#try with decisiontree and randomforest
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor

# %%
dtc= DecisionTreeClassifier()
rdf=RandomForestClassifier()

# %%
#training algorithms
dtc.fit(x_train,y_train)
rdf.fit(x_train,y_train)
print("your algorithm is fit")
# Out:
# your algorithm is fit

# %%
print("Decision tree score:")
print(dtc.score(x_train,y_train)*100)
print(dtc.score(x_test,y_test['satisfaction_satisfied'])*100)
print("Random Forest score:")
print(rdf.score(x_train,y_train)*100)
print(rdf.score(x_test,y_test['satisfaction_satisfied'])*100)
#random forest is extende version of decision tree.
#overfit-->99% in training ##difference-->5 se kaam hona chahiye
# Out:
# Decision tree score:
# 99.96500754147813
# 81.05603552294995
# Random Forest score:
# 99.95897435897436
# 87.1760220087842

# %%
import os, joblib 
os.makedirs('models',exist_ok=True) 
joblib.dump(dtc,'./models/decisiontree.lb') 
joblib.dump(rdf,'./models/randomforest.lb') 
print('your model is saved!')
# Out:
# your model is saved!

# %%
#hyperparameter tuning
#depth kaam karna ke hume decision lene mei aur easy hota h, yeh help karta h
rdf2=RandomForestClassifier(n_estimators=150,max_depth=14,min_samples_split=40)

# %%
rdf2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=14, min_samples_split=40, n_estimators=150)

# %%
print("Random Forest score:")
print(rdf2.score(x_train,y_train)*100)
print(rdf2.score(x_test,y_test['satisfaction_satisfied'])*100)
# Out:
# Random Forest score:
# 88.75294117647059
# 88.11236063516579

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
from sklearn.ensemble import RandomForestClassifier
rdf3=RandomForestClassifier() #default parameters

# %%
parameters={"n_estimators":[85,95,120,155],"max_depth":[10,15,20,25],"min_samples_split":[40,30,50]}

gridsearchcv=GridSearchCV(estimator=rdf3,param_grid=parameters)

# %%
rdf4=RandomForestClassifier(max_depth= 20, min_samples_split= 50, n_estimators= 120)

# %%
rdf4.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_split=50, n_estimators=120)

# %%
gridsearchcv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 15, 20, 25],
#                          'min_samples_split': [40, 30, 50],
#                          'n_estimators': [85, 95, 120, 155]})

# %%
gridsearchcv.best_params_
# Out:
# {'max_depth': 20, 'min_samples_split': 50, 'n_estimators': 155}

# %%
rdf4=RandomForestClassifier(max_depth=20,min_samples_split=50,n_estimators=155)
rdf4.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_split=50, n_estimators=155)

# %%
print("Random Forest score:")
print(rdf4.score(x_train,y_train)*100)
print(rdf4.score(x_test,y_test['satisfaction_satisfied'])*100)
# Out:
# Random Forest score:
# 89.1740573152338
# 88.10270765963608
